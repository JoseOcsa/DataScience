# %% [markdown]
# ## 1. Buscar el mayor y el menor valor
# Dada la tupla numeros = (15, 8, 42, 3, 27, 19, 5), obtén el número mayor, el menor y la
# diferencia entre ambos.

# %%
tupla = (15, 8, 42, 3, 27, 19, 5)
minimo_numero = min(tupla)
maximo_numero = max(tupla)
diff = maximo_numero - minimo_numero
print(
    f"Maximo numero: {maximo_numero}\nMinimo numero: {minimo_numero}\ndiff: {diff}"
)
# Out:
# Maximo numero: 42
# Minimo numero: 3
# diff: 39

# %% [markdown]
# ## 2. Contar ocurrencias
# Dada la tupla datos = (5, 8, 5, 1, 9, 5, 2, 8, 5, 3), solicita un número al usuario y muestra
# cuántas veces aparece sin convertir la tupla en lista.

# %%
datos = (5,8, 5, 1, 9, 5, 2, 8, 5, 3)
Entrada=int(input("Ingresa numero que deseas buscar:"))
contado=datos.count(Entrada)
print(f"Las veces que aparece el {Entrada} son {contado} veces")
# Out:
# Las veces que aparece el 5 son 4 veces

# %% [markdown]
# ## 3. Encontrar la primera posición
# Dada la tupla nombres = ('Ana','Luis','Pedro','María','Luis','Carlos'), solicita un nombre y
# muestra su primera posición o un mensaje si no existe.

# %%
nombres = ('Ana','Luis','Pedro','María','Luis','Carlos')
name=str(input("Ingresa el nombre que desees:"))
name_transformado=name.title()

for nombre in nombres:
    if name_transformado == nombre:
        tupla1=nombres.index(name_transformado)
        print(f"El nombre de {name_transformado} se encuentra en la posicion {tupla1}")
if name_transformado not in nombres:
    print(f"El nombre de {name_transformado} no existe")
# Out:
# El nombre de Carlos se encuentra en la posicion 5

# %% [markdown]
# ## 4. Estadísticas de una tupla
# Con notas = (18,15,20,11,14,17,19), calcula promedio, máxima, mínima y cantidad de
# aprobados.

# %%
notas = (18,15,20,11,14,17,19)
minimo = min(notas)
maximo = max(notas)
prom = round(sum(notas)/len(notas),2)
aprobados=0
print(f"Maxima nota: {maximo}\nMinima nota: {minimo}\nPromedio: {prom}")
for nota in notas:
    if nota> minimo:
        aprobados += 1
print(F"La cantidad de aprobados son: {aprobados} estudiantes")
# Out:
# Maxima nota: 20
# Minima nota: 11
# Promedio: 16.29
# La cantidad de aprobados son: 6 estudiantes

# %% [markdown]
# ## 5. Tuplas dentro de una lista
# Con ventas=[('Lunes',120),('Martes',150),('Miércoles',95),('Jueves',180),('Viernes',210)],
# calcula el día con mayor venta, el total y el promedio.

# %%
ventas=[('Lunes',120),('Martes',150),('Miércoles',95),('Jueves',180),('Viernes',210)]
venta_mayor = 0
total_ventas = 0
for dia, venta in ventas:
    total_ventas = total_ventas + venta

    if venta > venta_mayor:
        venta_mayor = venta
        dia_mayor = dia
promedio = total_ventas / len(ventas)
print(f"El dia con mayor venta fue: {dia_mayor}")
print(f"La mayor venta durante la semana fue : {venta_mayor}")
print(f"La venta total fue : {total_ventas}")
print(f"El promedio de ventas es: {promedio}")
# Out:
# El dia con mayor venta fue: Viernes
# La mayor venta durante la semana fue : 210
# La venta total fue : 755
# El promedio de ventas es: 151.0
