# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
lista_enteros=[0,1,2,3,4,5]
lista_nombres=["juan","rosa","maria","luna"]
lista_mixta=[0,1,2,"maria","luna"]

# %%
for item in lista_mixta:
    print(item)
# Out:
# 0
# 1
# 2
# maria
# luna

# %%
type(lista_enteros)
# Out:
# list

# %%
#Append para insertar elementos en una lista
lista_enteros.append([8,3,4])
print(lista_enteros)
# Out:
# [0, 1, 2, 3, 4, 5, 8, [8, 3, 4]]

# %%
lista_enteros.insert(1,"juAN")
print(lista_enteros)
# Out:
# [0, 'juAN', 'juAN', 1, 2, 3, 4, 5, 8, 'juAN', 'juAN', [8, 3, 4]]

# %%
lista_enteros.remove("juAN")
print(lista_enteros)
# Out:
# [0, 1, 2, 3, 5, 8, [8, 3, 4]]

# %%
#remueve el ultimo elemento de la lista
lista_enteros.pop()
# Out:
# [8, 3, 4]

# %%
while "juAN" in lista_enteros:
    lista_enteros.remove("juAN")

lista_enteros.insert(-1, "juAN")

# %%
lista_num=[5,1,2,3,4]
sorted(lista_num,reverse=True)
# Out:
# [5, 4, 3, 2, 1]
