# %%
print("Hello world")
# Out:
# Hello world

# %%
#Variable de texto o cadena o string
nombre="Jose" 
apellido= "Ocsa"
mi_nombre_completo=f"mi nombre completo es: {nombre} {apellido}"
print(mi_nombre_completo)
#Variables de enteros o int
edad: int =25
#Variables float (decimales)
sueldo: float=9.99
print("Mi edad dentro de 5 years",edad+5)
print("Mi edad hace  5 years",edad-5)
print("El doble de mi edad",edad*2)
print("La mitad de mi edad",edad/2)
print("La mitad de mi edad(cociente)",edad//2)
print("El resto de mi edad(residuo)",edad % 2)
# Out:
# mi nombre completo es: Jose Ocsa
# Mi edad dentro de 5 years 30
# Mi edad hace  5 years 20
# El doble de mi edad 50
# La mitad de mi edad 12.5
# La mitad de mi edad(cociente) 12
# El resto de mi edad(residuo) 1

# %%
nombre = input("Ingresa tu nombre:")

# %%
print(nombre)
# Out:
# jose

# %%
print(edad+5)
# Out:
# 30

# %%
edad_int=int(edad)

# %%
print(type(edad))
# Out:
# <class 'int'>

# %%
print(str(edad)+"5")
# Out:
# 255
