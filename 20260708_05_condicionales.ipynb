# %% [markdown]
# ## CONDICIONALES
#
# SI SE CUMPLE ESTA CONDICION
# - PROCESO 1
# SI SE CUMPLE ESTA OTRA CONDICION
# - PROCESO 2
# SI NO SE CUMPLE NINGUNA DE LA DOS
# - PROCESO por defecto o default
#
# if soy mayor de 18
#     soy mayor de edad
# si edad es mayor de 13
#     soy adolecente
# si no soy mayor  de 13
#     soy infante

# %%
edad=int(input("Ingresa tu edad"))
if edad>=18:
    print("soy un adulto")
elif edad >=13:
    print("soy un adolescente")
else:
    print("soy infante")
# Out:
# soy infante

# %% [markdown]
# Elif pertenece a un mismo bloque , if empieza la condicional y else la termina

# %%
temp_sensor_1= float(input("Ingresa temperatura vista"))
if temp_sensor_1>15 and temp_sensor_1>30:
    print("peligro")
else :
    print ("Temperatura normal")
# Out:
# Temperatura normal

# %%
numero=float(input("Ingresa un numero (negativo o positivo):"))
if numero <=0:
    print("negativo")
elif numero >=0:
    print("positivo")
else:
    print("El numero es 0")
# Determinar si el numero es par o impar
if numero%2 == 0:
    print("Tu numero es par")
else:
    print("Tu nummero es impar")
# Out:
# negativo
# Tu numero es par
